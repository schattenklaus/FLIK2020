# %% [markdown]
# # Explore overfitting and underfitting

# %% [markdown]
# In both of the previous notebooks—classifying movie reviews, and predicting housing prices—we saw that the accuracy of our model on the validation data would peak after training for a number of epochs, and would then start decreasing.
#
# In other words, our model would *overfit* to the training data. Learning how to deal with overfitting is important. Although it's often possible to achieve high accuracy on the *training set*, what we really want is to develop models that generalize well to a *testing data* (or data they haven't seen before).
#
# The opposite of overfitting is *underfitting*. Underfitting occurs when there is still room for improvement on the test data. This can happen for a number of reasons: If the model is not powerful enough, is over-regularized, or has simply not been trained long enough. This means the network has not learned the relevant patterns in the training data.
#
# If you train for too long though, the model will start to overfit and learn patterns from the training data that don't generalize to the test data. We need to strike a balance. Understanding how to train for an appropriate number of epochs as we'll explore below is a useful skill.
#
# To prevent overfitting, the best solution is to use more training data. A model trained on more data will naturally generalize better. When that is no longer possible, the next best solution is to use techniques like regularization. These place constraints on the quantity and type of information your model can store.  If a network can only afford to memorize a small number of patterns, the optimization process will force it to focus on the most prominent patterns, which have a better chance of generalizing well.
#
# In this notebook, we'll explore two common regularization techniques—weight regularization and dropout—and use them to improve our IMDB movie review classification notebook.

# %%
# %matplotlib inline
import tensorflow as tf
from tensorflow import keras
tf.keras.backend.clear_session()

import numpy as np
import matplotlib.pyplot as plt


keras.__version__
# Out:
# 207331

# %% [markdown]
# ## Download the IMDB dataset
#
# Rather than using an embedding as in the previous notebook, here we will multi-hot encode the sentences. This model will quickly overfit to the training set. It will be used to demonstrate when overfitting occurs, and how to fight it.
#
# Multi-hot-encoding our lists means turning them into vectors of 0s and 1s. Concretely, this would mean for instance turning the sequence  `[3, 5]` into a 10,000-dimensional vector that would be all-zeros except for indices 3 and 5, which would be ones.

# %%
NUM_WORDS = 10000

(train_data, train_labels), (test_data, test_labels) = keras.datasets.imdb.load_data(num_words=NUM_WORDS)

def multi_hot_sequences(sequences, dimension):
    # Create an all-zero matrix of shape (len(sequences), dimension)
    results = np.zeros((len(sequences), dimension))
    for i, word_indices in enumerate(sequences):
        results[i, word_indices] = 1.0  # set specific indices of results[i] to 1s
    return results


train_data = multi_hot_sequences(train_data, dimension=NUM_WORDS)
test_data = multi_hot_sequences(test_data, dimension=NUM_WORDS)

# %% [markdown]
# Let's look at one of the resulting multi-hot vectors. The word indices are sorted by frequency, so it is expected that there are more 1-values near index zero, as we can see in this plot:

# %%
plt.plot(train_data[0])

# %% [markdown]
# ## Demonstrate overfitting
#
# The simplest way to prevent overfitting is to reduce the size of the model, i.e. the number of learnable parameters in the model (which is determined by the number of layers and the number of units per layer). In deep learning, the number of learnable parameters in a model is often referred to as the model's "capacity". Intuitively, a model with more parameters will have more "memorization capacity" and therefore will be able to easily learn a perfect dictionary-like mapping between training samples and their targets, a mapping without any generalization power, but this would be useless when making predictions on previously unseen data.
#
# Always keep this in mind: deep learning models tend to be good at fitting to the training data, but the real challenge is generalization, not fitting.
#
# On the other hand, if the network has limited memorization resources, it will not be able to learn the mapping as easily. To minimize its loss, it will have to learn compressed representations that have more predictive power. At the same time, if you make your model too small, it will have difficulty fitting to the training data. There is a balance between "too much capacity" and "not enough capacity".
#
# Unfortunately, there is no magical formula to determine the right size or architecture of your model (in terms of the number of layers, or what the right size for each layer). You will have to experiment using a series of different architectures.
#
# To find an appropriate model size, it's best to start with relatively few layers and parameters, then begin increasing the size of the layers or adding new layers until you see diminishing returns on the validation loss. Let's try this on our movie review classification network.
#
# We'll create a simple model using only ```Dense``` layers as a baseline, then create smaller and larger versions, and compare them.

# %% [markdown]
# ### Create a baseline model

# %%
baseline_model = keras.Sequential([
    # `input_shape` is only required here so that `.summary` works. 
    keras.layers.Dense(16, activation='relu', input_shape=(NUM_WORDS,)),
    keras.layers.Dense(16, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

baseline_model.compile(optimizer='adam',
                       loss='binary_crossentropy',
                       metrics=['accuracy', 'binary_crossentropy'])

baseline_model.summary()
# Out:
# W1008 23:25:13.680742 35184372383184 deprecation.py:506] From /software/ml/JupyterHub/conda-env-20191018-0822/lib/python3.6/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 16)                160016
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                272
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 160,305
# Trainable params: 160,305
# Non-trainable params: 0
# _________________________________________________________________

# %%
baseline_history = baseline_model.fit(train_data,
                                      train_labels,
                                      epochs=20,
                                      batch_size=512,
                                      validation_data=(test_data, test_labels),
                                      verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
# 25000/25000 - 1s - loss: 0.5294 - acc: 0.8003 - binary_crossentropy: 0.5294 - val_loss: 0.3738 - val_acc: 0.8662 - val_binary_crossentropy: 0.3738
# Epoch 2/20
# 25000/25000 - 1s - loss: 0.2721 - acc: 0.9042 - binary_crossentropy: 0.2721 - val_loss: 0.2874 - val_acc: 0.8878 - val_binary_crossentropy: 0.2874
# Epoch 3/20
# 25000/25000 - 1s - loss: 0.1924 - acc: 0.9323 - binary_crossentropy: 0.1924 - val_loss: 0.2862 - val_acc: 0.8851 - val_binary_crossentropy: 0.2862
# Epoch 4/20
# 25000/25000 - 1s - loss: 0.1546 - acc: 0.9458 - binary_crossentropy: 0.1546 - val_loss: 0.3078 - val_acc: 0.8794 - val_binary_crossentropy: 0.3078
# Epoch 5/20
# 25000/25000 - 1s - loss: 0.1268 - acc: 0.9569 - binary_crossentropy: 0.1268 - val_loss: 0.3282 - val_acc: 0.8772 - val_binary_crossentropy: 0.3282
# Epoch 6/20
# 25000/25000 - 1s - loss: 0.1058 - acc: 0.9665 - binary_crossentropy: 0.1058 - val_loss: 0.3579 - val_acc: 0.8731 - val_binary_crossentropy: 0.3579
# Epoch 7/20
# 25000/25000 - 1s - loss: 0.0885 - acc: 0.9726 - binary_crossentropy: 0.0885 - val_loss: 0.3916 - val_acc: 0.8695 - val_binary_crossentropy: 0.3916
# Epoch 8/20
# 25000/25000 - 1s - loss: 0.0746 - acc: 0.9785 - binary_crossentropy: 0.0746 - val_loss: 0.4280 - val_acc: 0.8660 - val_binary_crossentropy: 0.4280
# Epoch 9/20
# 25000/25000 - 1s - loss: 0.0603 - acc: 0.9846 - binary_crossentropy: 0.0603 - val_loss: 0.4659 - val_acc: 0.8647 - val_binary_crossentropy: 0.4659
# Epoch 10/20
# 25000/25000 - 1s - loss: 0.0502 - acc: 0.9881 - binary_crossentropy: 0.0502 - val_loss: 0.5089 - val_acc: 0.8604 - val_binary_crossentropy: 0.5089
# Epoch 11/20
# 25000/25000 - 1s - loss: 0.0383 - acc: 0.9923 - binary_crossentropy: 0.0383 - val_loss: 0.5503 - val_acc: 0.8591 - val_binary_crossentropy: 0.5503
# Epoch 12/20
# 25000/25000 - 1s - loss: 0.0292 - acc: 0.9951 - binary_crossentropy: 0.0292 - val_loss: 0.5930 - val_acc: 0.8573 - val_binary_crossentropy: 0.5930
# Epoch 13/20
# 25000/25000 - 1s - loss: 0.0222 - acc: 0.9971 - binary_crossentropy: 0.0222 - val_loss: 0.6350 - val_acc: 0.8560 - val_binary_crossentropy: 0.6350
# Epoch 14/20
# 25000/25000 - 1s - loss: 0.0164 - acc: 0.9984 - binary_crossentropy: 0.0164 - val_loss: 0.6840 - val_acc: 0.8556 - val_binary_crossentropy: 0.6840
# Epoch 15/20
# 25000/25000 - 1s - loss: 0.0122 - acc: 0.9991 - binary_crossentropy: 0.0122 - val_loss: 0.7228 - val_acc: 0.8559 - val_binary_crossentropy: 0.7228
# Epoch 16/20
# 25000/25000 - 1s - loss: 0.0090 - acc: 0.9995 - binary_crossentropy: 0.0090 - val_loss: 0.7685 - val_acc: 0.8553 - val_binary_crossentropy: 0.7685
# Epoch 17/20
# 25000/25000 - 1s - loss: 0.0068 - acc: 0.9997 - binary_crossentropy: 0.0068 - val_loss: 0.8059 - val_acc: 0.8559 - val_binary_crossentropy: 0.8059
# Epoch 18/20
# 25000/25000 - 1s - loss: 0.0051 - acc: 0.9998 - binary_crossentropy: 0.0051 - val_loss: 0.8446 - val_acc: 0.8553 - val_binary_crossentropy: 0.8446
# Epoch 19/20
# 25000/25000 - 1s - loss: 0.0040 - acc: 0.9999 - binary_crossentropy: 0.0040 - val_loss: 0.8804 - val_acc: 0.8548 - val_binary_crossentropy: 0.8804
# Epoch 20/20
# 25000/25000 - 1s - loss: 0.0032 - acc: 1.0000 - binary_crossentropy: 0.0032 - val_loss: 0.9108 - val_acc: 0.8551 - val_binary_crossentropy: 0.9108

# %% [markdown]
# ### Create a smaller model

# %% [markdown]
# Let's create a model with less hidden units to compare against the baseline model that we just created:

# %%
smaller_model = keras.Sequential([
    keras.layers.Dense(4, activation='relu', input_shape=(NUM_WORDS,)),
    keras.layers.Dense(4, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

smaller_model.compile(optimizer='adam',
                loss='binary_crossentropy',
                metrics=['accuracy', 'binary_crossentropy'])

smaller_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 4)                 40004
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 20
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 5
# =================================================================
# Total params: 40,029
# Trainable params: 40,029
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# And train the model using the same data:

# %%
smaller_history = smaller_model.fit(train_data,
                                    train_labels,
                                    epochs=20,
                                    batch_size=512,
                                    validation_data=(test_data, test_labels),
                                    verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
# 25000/25000 - 2s - loss: 0.5954 - acc: 0.7608 - binary_crossentropy: 0.5954 - val_loss: 0.4957 - val_acc: 0.8391 - val_binary_crossentropy: 0.4957
# Epoch 2/20
# 25000/25000 - 2s - loss: 0.4071 - acc: 0.8787 - binary_crossentropy: 0.4071 - val_loss: 0.3807 - val_acc: 0.8725 - val_binary_crossentropy: 0.3807
# Epoch 3/20
# 25000/25000 - 1s - loss: 0.3075 - acc: 0.9044 - binary_crossentropy: 0.3075 - val_loss: 0.3262 - val_acc: 0.8812 - val_binary_crossentropy: 0.3262
# Epoch 4/20
# 25000/25000 - 1s - loss: 0.2489 - acc: 0.9196 - binary_crossentropy: 0.2489 - val_loss: 0.2980 - val_acc: 0.8858 - val_binary_crossentropy: 0.2980
# Epoch 5/20
# 25000/25000 - 1s - loss: 0.2102 - acc: 0.9316 - binary_crossentropy: 0.2102 - val_loss: 0.2859 - val_acc: 0.8873 - val_binary_crossentropy: 0.2859
# Epoch 6/20
# 25000/25000 - 1s - loss: 0.1834 - acc: 0.9399 - binary_crossentropy: 0.1834 - val_loss: 0.2831 - val_acc: 0.8878 - val_binary_crossentropy: 0.2831
# Epoch 7/20
# 25000/25000 - 1s - loss: 0.1621 - acc: 0.9484 - binary_crossentropy: 0.1621 - val_loss: 0.2866 - val_acc: 0.8854 - val_binary_crossentropy: 0.2866
# Epoch 8/20
# 25000/25000 - 1s - loss: 0.1454 - acc: 0.9542 - binary_crossentropy: 0.1454 - val_loss: 0.2937 - val_acc: 0.8838 - val_binary_crossentropy: 0.2937
# Epoch 9/20
# 25000/25000 - 1s - loss: 0.1314 - acc: 0.9596 - binary_crossentropy: 0.1314 - val_loss: 0.3100 - val_acc: 0.8781 - val_binary_crossentropy: 0.3100
# Epoch 10/20
# 25000/25000 - 1s - loss: 0.1199 - acc: 0.9630 - binary_crossentropy: 0.1199 - val_loss: 0.3161 - val_acc: 0.8780 - val_binary_crossentropy: 0.3161
# Epoch 11/20
# 25000/25000 - 1s - loss: 0.1090 - acc: 0.9674 - binary_crossentropy: 0.1090 - val_loss: 0.3279 - val_acc: 0.8760 - val_binary_crossentropy: 0.3279
# Epoch 12/20
# 25000/25000 - 1s - loss: 0.0998 - acc: 0.9704 - binary_crossentropy: 0.0998 - val_loss: 0.3423 - val_acc: 0.8733 - val_binary_crossentropy: 0.3423
# Epoch 13/20
# 25000/25000 - 1s - loss: 0.0914 - acc: 0.9743 - binary_crossentropy: 0.0914 - val_loss: 0.3559 - val_acc: 0.8719 - val_binary_crossentropy: 0.3559
# Epoch 14/20
# 25000/25000 - 1s - loss: 0.0838 - acc: 0.9771 - binary_crossentropy: 0.0838 - val_loss: 0.3730 - val_acc: 0.8694 - val_binary_crossentropy: 0.3730
# Epoch 15/20
# 25000/25000 - 1s - loss: 0.0771 - acc: 0.9795 - binary_crossentropy: 0.0771 - val_loss: 0.3866 - val_acc: 0.8681 - val_binary_crossentropy: 0.3866
# Epoch 16/20
# 25000/25000 - 1s - loss: 0.0712 - acc: 0.9818 - binary_crossentropy: 0.0712 - val_loss: 0.4036 - val_acc: 0.8664 - val_binary_crossentropy: 0.4036
# Epoch 17/20
# 25000/25000 - 1s - loss: 0.0644 - acc: 0.9848 - binary_crossentropy: 0.0644 - val_loss: 0.4189 - val_acc: 0.8655 - val_binary_crossentropy: 0.4189
# Epoch 18/20
# 25000/25000 - 1s - loss: 0.0588 - acc: 0.9872 - binary_crossentropy: 0.0588 - val_loss: 0.4377 - val_acc: 0.8634 - val_binary_crossentropy: 0.4377
# Epoch 19/20
# 25000/25000 - 1s - loss: 0.0540 - acc: 0.9892 - binary_crossentropy: 0.0540 - val_loss: 0.4520 - val_acc: 0.8628 - val_binary_crossentropy: 0.4520
# Epoch 20/20
# 25000/25000 - 1s - loss: 0.0494 - acc: 0.9907 - binary_crossentropy: 0.0494 - val_loss: 0.4713 - val_acc: 0.8613 - val_binary_crossentropy: 0.4713

# %% [markdown]
# ### Create a bigger model
#
# As an exercise, you can create an even larger model, and see how quickly it begins overfitting.  Next, let's add to this benchmark a network that has much more capacity, far more than the problem would warrant:

# %%
bigger_model = keras.models.Sequential([
    keras.layers.Dense(512, activation='relu', input_shape=(NUM_WORDS,)),
    keras.layers.Dense(512, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

bigger_model.compile(optimizer='adam',
                     loss='binary_crossentropy',
                     metrics=['accuracy','binary_crossentropy'])

bigger_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 512)               5120512
# _________________________________________________________________
# dense_7 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 5,383,681
# Trainable params: 5,383,681
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# And, again, train the model using the same data:

# %%
bigger_history = bigger_model.fit(train_data, train_labels,
                                  epochs=20,
                                  batch_size=512,
                                  validation_data=(test_data, test_labels),
                                  verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
# 25000/25000 - 2s - loss: 0.3527 - acc: 0.8493 - binary_crossentropy: 0.3527 - val_loss: 0.3196 - val_acc: 0.8672 - val_binary_crossentropy: 0.3196
# Epoch 2/20
# 25000/25000 - 1s - loss: 0.1450 - acc: 0.9477 - binary_crossentropy: 0.1450 - val_loss: 0.3311 - val_acc: 0.8732 - val_binary_crossentropy: 0.3311
# Epoch 3/20
# 25000/25000 - 1s - loss: 0.0471 - acc: 0.9868 - binary_crossentropy: 0.0471 - val_loss: 0.4397 - val_acc: 0.8694 - val_binary_crossentropy: 0.4397
# Epoch 4/20
# 25000/25000 - 1s - loss: 0.0066 - acc: 0.9991 - binary_crossentropy: 0.0066 - val_loss: 0.5832 - val_acc: 0.8682 - val_binary_crossentropy: 0.5832
# Epoch 5/20
# 25000/25000 - 1s - loss: 7.6063e-04 - acc: 1.0000 - binary_crossentropy: 7.6063e-04 - val_loss: 0.6757 - val_acc: 0.8694 - val_binary_crossentropy: 0.6757
# Epoch 6/20
# 25000/25000 - 1s - loss: 2.3175e-04 - acc: 1.0000 - binary_crossentropy: 2.3175e-04 - val_loss: 0.7185 - val_acc: 0.8700 - val_binary_crossentropy: 0.7185
# Epoch 7/20
# 25000/25000 - 1s - loss: 1.4241e-04 - acc: 1.0000 - binary_crossentropy: 1.4241e-04 - val_loss: 0.7480 - val_acc: 0.8700 - val_binary_crossentropy: 0.7480
# Epoch 8/20
# 25000/25000 - 1s - loss: 1.0220e-04 - acc: 1.0000 - binary_crossentropy: 1.0220e-04 - val_loss: 0.7705 - val_acc: 0.8703 - val_binary_crossentropy: 0.7705
# Epoch 9/20
# 25000/25000 - 1s - loss: 7.7985e-05 - acc: 1.0000 - binary_crossentropy: 7.7985e-05 - val_loss: 0.7892 - val_acc: 0.8704 - val_binary_crossentropy: 0.7892
# Epoch 10/20
# 25000/25000 - 1s - loss: 6.1877e-05 - acc: 1.0000 - binary_crossentropy: 6.1877e-05 - val_loss: 0.8055 - val_acc: 0.8704 - val_binary_crossentropy: 0.8055
# Epoch 11/20
# 25000/25000 - 1s - loss: 5.0240e-05 - acc: 1.0000 - binary_crossentropy: 5.0240e-05 - val_loss: 0.8202 - val_acc: 0.8705 - val_binary_crossentropy: 0.8202
# Epoch 12/20
# 25000/25000 - 1s - loss: 4.1770e-05 - acc: 1.0000 - binary_crossentropy: 4.1770e-05 - val_loss: 0.8335 - val_acc: 0.8708 - val_binary_crossentropy: 0.8335
# Epoch 13/20
# 25000/25000 - 1s - loss: 3.5104e-05 - acc: 1.0000 - binary_crossentropy: 3.5104e-05 - val_loss: 0.8454 - val_acc: 0.8709 - val_binary_crossentropy: 0.8454
# Epoch 14/20
# 25000/25000 - 1s - loss: 3.0004e-05 - acc: 1.0000 - binary_crossentropy: 3.0004e-05 - val_loss: 0.8567 - val_acc: 0.8707 - val_binary_crossentropy: 0.8567
# Epoch 15/20
# 25000/25000 - 1s - loss: 2.5876e-05 - acc: 1.0000 - binary_crossentropy: 2.5876e-05 - val_loss: 0.8671 - val_acc: 0.8706 - val_binary_crossentropy: 0.8671
# Epoch 16/20
# 25000/25000 - 1s - loss: 2.2566e-05 - acc: 1.0000 - binary_crossentropy: 2.2566e-05 - val_loss: 0.8771 - val_acc: 0.8707 - val_binary_crossentropy: 0.8771
# Epoch 17/20
# 25000/25000 - 1s - loss: 1.9808e-05 - acc: 1.0000 - binary_crossentropy: 1.9808e-05 - val_loss: 0.8863 - val_acc: 0.8705 - val_binary_crossentropy: 0.8863
# Epoch 18/20
# 25000/25000 - 1s - loss: 1.7515e-05 - acc: 1.0000 - binary_crossentropy: 1.7515e-05 - val_loss: 0.8952 - val_acc: 0.8705 - val_binary_crossentropy: 0.8952
# Epoch 19/20
# 25000/25000 - 1s - loss: 1.5592e-05 - acc: 1.0000 - binary_crossentropy: 1.5592e-05 - val_loss: 0.9034 - val_acc: 0.8709 - val_binary_crossentropy: 0.9034
# Epoch 20/20
# 25000/25000 - 1s - loss: 1.3959e-05 - acc: 1.0000 - binary_crossentropy: 1.3959e-05 - val_loss: 0.9115 - val_acc: 0.8710 - val_binary_crossentropy: 0.9115

# %% [markdown]
# ### Plot the training and validation loss
#
# <!--TODO(markdaoust): This should be a one-liner with tensorboard -->

# %% [markdown]
# The solid lines show the training loss, and the dashed lines show the validation loss (remember: a lower validation loss indicates a better model). Here, the smaller network begins overfitting later than the baseline model (after 6 epochs rather than 4) and its performance degrades much more slowly once it starts overfitting.

# %%
def plot_history(histories, key='binary_crossentropy'):
  plt.figure(figsize=(16,10))
    
  for name, history in histories:
    val = plt.plot(history.epoch, history.history['val_'+key],
                   '--', label=name.title()+' Val')
    plt.plot(history.epoch, history.history[key], color=val[0].get_color(),
             label=name.title()+' Train')

  plt.xlabel('Epochs')
  plt.ylabel(key.replace('_',' ').title())
  plt.legend()

  plt.xlim([0,max(history.epoch)])


plot_history([('baseline', baseline_history),
              ('smaller', smaller_history),
              ('bigger', bigger_history)])

# %% [markdown]
# Notice that the larger network begins overfitting almost right away, after just one epoch, and overfits much more severely. The more capacity the network has, the quicker it will be able to model the training data (resulting in a low training loss), but the more susceptible it is to overfitting (resulting in a large difference between the training and validation loss).

# %% [markdown]
# ## Strategies

# %% [markdown]
# ### Add weight regularization

# %% [markdown]
# You may be familiar with Occam's Razor principle: given two explanations for something, the explanation most likely to be correct is the "simplest" one, the one that makes the least amount of assumptions. This also applies to the models learned by neural networks: given some training data and a network architecture, there are multiple sets of weights values (multiple models) that could explain the data, and simpler models are less likely to overfit than complex ones.
#
# A "simple model" in this context is a model where the distribution of parameter values has less entropy (or a model with fewer parameters altogether, as we saw in the section above). Thus a common way to mitigate overfitting is to put constraints on the complexity of a network by forcing its weights only to take small values, which makes the distribution of weight values more "regular". This is called "weight regularization", and it is done by adding to the loss function of the network a cost associated with having large weights. This cost comes in two flavors:
#
# * L1 regularization, where the cost added is proportional to the absolute value of the weights coefficients (i.e. to what is called the "L1 norm" of the weights).
#
# * L2 regularization, where the cost added is proportional to the square of the value of the weights coefficients (i.e. to what is called the "L2 norm" of the weights). L2 regularization is also called weight decay in the context of neural networks. Don't let the different name confuse you: weight decay is mathematically the exact same as L2 regularization.
#
# In Keras, weight regularization is added by passing weight regularizer instances to layers as keyword arguments. Let's add L2 weight regularization now.

# %%
l2_model = keras.models.Sequential([
    keras.layers.Dense(16, kernel_regularizer=keras.regularizers.l2(0.001),
                       activation='relu', input_shape=(NUM_WORDS,)),
    keras.layers.Dense(16, kernel_regularizer=keras.regularizers.l2(0.001),
                       activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

l2_model.compile(optimizer='adam',
                 loss='binary_crossentropy',
                 metrics=['accuracy', 'binary_crossentropy'])

l2_model_history = l2_model.fit(train_data, train_labels,
                                epochs=20,
                                batch_size=512,
                                validation_data=(test_data, test_labels),
                                verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
# 25000/25000 - 2s - loss: 0.5245 - acc: 0.8096 - binary_crossentropy: 0.4839 - val_loss: 0.3786 - val_acc: 0.8760 - val_binary_crossentropy: 0.3357
# Epoch 2/20
# 25000/25000 - 1s - loss: 0.2995 - acc: 0.9078 - binary_crossentropy: 0.2520 - val_loss: 0.3351 - val_acc: 0.8863 - val_binary_crossentropy: 0.2840
# Epoch 3/20
# 25000/25000 - 1s - loss: 0.2458 - acc: 0.9313 - binary_crossentropy: 0.1919 - val_loss: 0.3425 - val_acc: 0.8849 - val_binary_crossentropy: 0.2867
# Epoch 4/20
# 25000/25000 - 1s - loss: 0.2245 - acc: 0.9419 - binary_crossentropy: 0.1668 - val_loss: 0.3636 - val_acc: 0.8782 - val_binary_crossentropy: 0.3043
# Epoch 5/20
# 25000/25000 - 1s - loss: 0.2090 - acc: 0.9495 - binary_crossentropy: 0.1487 - val_loss: 0.3757 - val_acc: 0.8762 - val_binary_crossentropy: 0.3143
# Epoch 6/20
# 25000/25000 - 1s - loss: 0.1976 - acc: 0.9547 - binary_crossentropy: 0.1352 - val_loss: 0.3901 - val_acc: 0.8742 - val_binary_crossentropy: 0.3272
# Epoch 7/20
# 25000/25000 - 1s - loss: 0.1904 - acc: 0.9576 - binary_crossentropy: 0.1267 - val_loss: 0.4122 - val_acc: 0.8694 - val_binary_crossentropy: 0.3478
# Epoch 8/20
# 25000/25000 - 1s - loss: 0.1843 - acc: 0.9594 - binary_crossentropy: 0.1192 - val_loss: 0.4262 - val_acc: 0.8687 - val_binary_crossentropy: 0.3605
# Epoch 9/20
# 25000/25000 - 1s - loss: 0.1788 - acc: 0.9612 - binary_crossentropy: 0.1122 - val_loss: 0.4444 - val_acc: 0.8644 - val_binary_crossentropy: 0.3772
# Epoch 10/20
# 25000/25000 - 1s - loss: 0.1734 - acc: 0.9645 - binary_crossentropy: 0.1057 - val_loss: 0.4529 - val_acc: 0.8659 - val_binary_crossentropy: 0.3846
# Epoch 11/20
# 25000/25000 - 1s - loss: 0.1666 - acc: 0.9676 - binary_crossentropy: 0.0979 - val_loss: 0.4654 - val_acc: 0.8634 - val_binary_crossentropy: 0.3961
# Epoch 12/20
# 25000/25000 - 1s - loss: 0.1620 - acc: 0.9697 - binary_crossentropy: 0.0923 - val_loss: 0.4830 - val_acc: 0.8620 - val_binary_crossentropy: 0.4127
# Epoch 13/20
# 25000/25000 - 1s - loss: 0.1560 - acc: 0.9733 - binary_crossentropy: 0.0853 - val_loss: 0.4959 - val_acc: 0.8615 - val_binary_crossentropy: 0.4249
# Epoch 14/20
# 25000/25000 - 1s - loss: 0.1516 - acc: 0.9745 - binary_crossentropy: 0.0800 - val_loss: 0.5120 - val_acc: 0.8585 - val_binary_crossentropy: 0.4401
# Epoch 15/20
# 25000/25000 - 1s - loss: 0.1481 - acc: 0.9764 - binary_crossentropy: 0.0760 - val_loss: 0.5236 - val_acc: 0.8596 - val_binary_crossentropy: 0.4507
# Epoch 16/20
# 25000/25000 - 1s - loss: 0.1447 - acc: 0.9778 - binary_crossentropy: 0.0710 - val_loss: 0.5380 - val_acc: 0.8566 - val_binary_crossentropy: 0.4640
# Epoch 17/20
# 25000/25000 - 1s - loss: 0.1393 - acc: 0.9794 - binary_crossentropy: 0.0655 - val_loss: 0.5500 - val_acc: 0.8581 - val_binary_crossentropy: 0.4760
# Epoch 18/20
# 25000/25000 - 1s - loss: 0.1356 - acc: 0.9829 - binary_crossentropy: 0.0612 - val_loss: 0.5620 - val_acc: 0.8574 - val_binary_crossentropy: 0.4874
# Epoch 19/20
# 25000/25000 - 1s - loss: 0.1308 - acc: 0.9838 - binary_crossentropy: 0.0565 - val_loss: 0.5653 - val_acc: 0.8567 - val_binary_crossentropy: 0.4908
# Epoch 20/20
# 25000/25000 - 1s - loss: 0.1247 - acc: 0.9875 - binary_crossentropy: 0.0504 - val_loss: 0.5759 - val_acc: 0.8563 - val_binary_crossentropy: 0.5019

# %% [markdown]
# ```l2(0.001)``` means that every coefficient in the weight matrix of the layer will add ```0.001 * weight_coefficient_value**2``` to the total loss of the network. Note that because this penalty is only added at training time, the loss for this network will be much higher at training than at test time.
#
# Here's the impact of our L2 regularization penalty:

# %%
plot_history([('baseline', baseline_history),
              ('l2', l2_model_history)])

# %% [markdown]
# As you can see, the L2 regularized model has become much more resistant to overfitting than the baseline model, even though both models have the same number of parameters.

# %% [markdown]
# ### Add dropout
#
# Dropout is one of the most effective and most commonly used regularization techniques for neural networks, developed by Hinton and his students at the University of Toronto. Dropout, applied to a layer, consists of randomly "dropping out" (i.e. set to zero) a number of output features of the layer during training. Let's say a given layer would normally have returned a vector [0.2, 0.5, 1.3, 0.8, 1.1] for a given input sample during training; after applying dropout, this vector will have a few zero entries distributed at random, e.g. [0, 0.5,
# 1.3, 0, 1.1]. The "dropout rate" is the fraction of the features that are being zeroed-out; it is usually set between 0.2 and 0.5. At test time, no units are dropped out, and instead the layer's output values are scaled down by a factor equal to the dropout rate, so as to balance for the fact that more units are active than at training time.
#
# In tf.keras you can introduce dropout in a network via the Dropout layer, which gets applied to the output of layer right before.
#
# Let's add two Dropout layers in our IMDB network to see how well they do at reducing overfitting:

# %%
dpt_model = keras.models.Sequential([
    keras.layers.Dense(16, activation='relu', input_shape=(NUM_WORDS,)),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(16, activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(1, activation='sigmoid')
])

dpt_model.compile(optimizer='adam',
                  loss='binary_crossentropy',
                  metrics=['accuracy','binary_crossentropy'])

dpt_model_history = dpt_model.fit(train_data, train_labels,
                                  epochs=20,
                                  batch_size=512,
                                  validation_data=(test_data, test_labels),
                                  verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
# 25000/25000 - 2s - loss: 0.6237 - acc: 0.6443 - binary_crossentropy: 0.6237 - val_loss: 0.4860 - val_acc: 0.8567 - val_binary_crossentropy: 0.4860
# Epoch 2/20
# 25000/25000 - 1s - loss: 0.4514 - acc: 0.8070 - binary_crossentropy: 0.4514 - val_loss: 0.3383 - val_acc: 0.8814 - val_binary_crossentropy: 0.3383
# Epoch 3/20
# 25000/25000 - 1s - loss: 0.3532 - acc: 0.8667 - binary_crossentropy: 0.3532 - val_loss: 0.2863 - val_acc: 0.8882 - val_binary_crossentropy: 0.2863
# Epoch 4/20
# 25000/25000 - 1s - loss: 0.2904 - acc: 0.8996 - binary_crossentropy: 0.2904 - val_loss: 0.2763 - val_acc: 0.8873 - val_binary_crossentropy: 0.2763
# Epoch 5/20
# 25000/25000 - 1s - loss: 0.2472 - acc: 0.9188 - binary_crossentropy: 0.2472 - val_loss: 0.2757 - val_acc: 0.8878 - val_binary_crossentropy: 0.2757
# Epoch 6/20
# 25000/25000 - 1s - loss: 0.2122 - acc: 0.9322 - binary_crossentropy: 0.2122 - val_loss: 0.2865 - val_acc: 0.8861 - val_binary_crossentropy: 0.2865
# Epoch 7/20
# 25000/25000 - 1s - loss: 0.1847 - acc: 0.9409 - binary_crossentropy: 0.1847 - val_loss: 0.3042 - val_acc: 0.8853 - val_binary_crossentropy: 0.3042
# Epoch 8/20
# 25000/25000 - 1s - loss: 0.1653 - acc: 0.9475 - binary_crossentropy: 0.1653 - val_loss: 0.3226 - val_acc: 0.8828 - val_binary_crossentropy: 0.3226
# Epoch 9/20
# 25000/25000 - 1s - loss: 0.1433 - acc: 0.9553 - binary_crossentropy: 0.1433 - val_loss: 0.3422 - val_acc: 0.8818 - val_binary_crossentropy: 0.3422
# Epoch 10/20
# 25000/25000 - 1s - loss: 0.1292 - acc: 0.9599 - binary_crossentropy: 0.1292 - val_loss: 0.3562 - val_acc: 0.8793 - val_binary_crossentropy: 0.3562
# Epoch 11/20
# 25000/25000 - 1s - loss: 0.1167 - acc: 0.9618 - binary_crossentropy: 0.1167 - val_loss: 0.3778 - val_acc: 0.8788 - val_binary_crossentropy: 0.3778
# Epoch 12/20
# 25000/25000 - 1s - loss: 0.1060 - acc: 0.9670 - binary_crossentropy: 0.1060 - val_loss: 0.4086 - val_acc: 0.8777 - val_binary_crossentropy: 0.4086
# Epoch 13/20
# 25000/25000 - 1s - loss: 0.0947 - acc: 0.9694 - binary_crossentropy: 0.0947 - val_loss: 0.4304 - val_acc: 0.8766 - val_binary_crossentropy: 0.4304
# Epoch 14/20
# 25000/25000 - 1s - loss: 0.0864 - acc: 0.9731 - binary_crossentropy: 0.0864 - val_loss: 0.4536 - val_acc: 0.8765 - val_binary_crossentropy: 0.4536
# Epoch 15/20
# 25000/25000 - 1s - loss: 0.0838 - acc: 0.9740 - binary_crossentropy: 0.0838 - val_loss: 0.4805 - val_acc: 0.8736 - val_binary_crossentropy: 0.4805
# Epoch 16/20
# 25000/25000 - 1s - loss: 0.0823 - acc: 0.9729 - binary_crossentropy: 0.0823 - val_loss: 0.4794 - val_acc: 0.8758 - val_binary_crossentropy: 0.4794
# Epoch 17/20
# 25000/25000 - 1s - loss: 0.0743 - acc: 0.9743 - binary_crossentropy: 0.0743 - val_loss: 0.5140 - val_acc: 0.8750 - val_binary_crossentropy: 0.5140
# Epoch 18/20
# 25000/25000 - 1s - loss: 0.0691 - acc: 0.9774 - binary_crossentropy: 0.0691 - val_loss: 0.5370 - val_acc: 0.8725 - val_binary_crossentropy: 0.5370
# Epoch 19/20
# 25000/25000 - 1s - loss: 0.0688 - acc: 0.9769 - binary_crossentropy: 0.0688 - val_loss: 0.5438 - val_acc: 0.8757 - val_binary_crossentropy: 0.5438
# Epoch 20/20
# 25000/25000 - 1s - loss: 0.0667 - acc: 0.9770 - binary_crossentropy: 0.0667 - val_loss: 0.5587 - val_acc: 0.8745 - val_binary_crossentropy: 0.5587

# %%
plot_history([('baseline', baseline_history),
              ('dropout', dpt_model_history)])

# %% [markdown]
# Adding dropout is a clear improvement over the baseline model.
#
#
# To recap: here the most common ways to prevent overfitting in neural networks:
#
# * Get more training data.
# * Reduce the capacity of the network.
# * Add weight regularization.
# * Add dropout.
#
# And two important approaches not covered in this guide are data-augmentation and batch normalization.

# %% [markdown]
# ### PLEASE RUN THIS COMMAND IF YOU FINISHED THE NOTEBOOK

# %%
import os
temp=os.getpid()
# !kill -9 $temp
